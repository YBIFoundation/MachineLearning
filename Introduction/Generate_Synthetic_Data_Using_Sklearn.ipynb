# %% [markdown]
# # **[YBI Foundation](https://www.ybifoundation.org/)**
# click to know more

# %% [markdown]
# **scikit-learn includes various random sample generators that can be used to build artificial datasets of controlled size and complexity.**

# %%
# import library

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **💻 Generate Synthetic Data (Make Regression)**

# %%
# import function

from sklearn.datasets import make_regression

# %%
# with coeficient of underline model return

X, y, w = make_regression( n_samples=1000, n_features=1, coef=True, bias=100, noise = 10, random_state=2529)

# %%
# without coeficient of underline model

X, y = make_regression( n_samples=1000, n_features=1, coef=False, bias=100, noise = 10, random_state=2529)

# %%
X.shape, y.shape
# Out:
# ((1000, 1), (1000,))

# %%
w
# Out:
# array(24.96405085)

# %%
plt.scatter(X, y, marker="o", c=y, s=25, edgecolor="k");

# %% [markdown]
# # **💻 Generate Synthetic Data (Make Classification)**

# %%
# import function

from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=1, n_classes=2,  random_state=2529)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=25, edgecolor="k");

# %% [markdown]
# # **💻 Generate Synthetic Data (Make Blobs)**

# %%
# import function

from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=1000, centers=3, n_features=2, random_state=2529)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=25, edgecolor="k");

# %% [markdown]
# # **💻 Generate Synthetic Data (Make Circles)**

# %%
# import function

from sklearn.datasets import make_circles

# %%
X, y = make_circles(n_samples = 1000, noise=0.3, factor = 0.5, random_state=2529)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=25, edgecolor="k");

# %% [markdown]
# # **💻 Generate Synthetic Data (Make Moons)**

# %%
# import function

from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples = 1000, noise=0.3, random_state=2529)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.scatter(X[:, 0], X[:, 1], marker="o", c=y, s=25, edgecolor="k");
